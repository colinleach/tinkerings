# %% [markdown]
# # Plotly
#
# Aimed at making interactive online graphics, Plotly is similar in some ways to Bokeh. However it is an open-source component of a commercial product, so beyond a certain (quite advanced) point it will need online credentials and maybe paid subscriptions. Also, the technical underpinnings are different.

# %%
# These are no longer essential:
# import plotly
# from plotly.offline import init_notebook_mode, iplot
# import plotly.graph_objs as go

# The new way to do it
import plotly.express as px

import pandas as pd
import numpy as np

# %% [markdown]
# Plotly itself is JavaScript-based with binding for a variety of languages.
#
# Python programmers will probably need integration with pandas, which has a tangled and sometimes infuriating history. Plotly v3 was not really compatible with pandas. For a long time, the recommendation was to use cufflinks as an add-in, but these kept being broken by Plotly API changes. An alternative package was Express, which ended up being incorporated into Plotly v4.
#
# The full software stack is then something like Plotly Express > plotly.graph_objects > plotly.js > d3.js

# %%
df = pd.read_pickle('sdss_colors.pkl')
df[:3]
# Out:
#           u         g         r         i         z specClass  redshift  \
# 0  18.06726  17.92133  17.76799  17.83525  17.74435       QSO  0.946076
# 1  19.46527  17.84728  17.00071  16.56581  16.20629    GALAXY  0.078311
# 2  18.65488  17.34237  16.79778  16.49659  16.24572    GALAXY  0.032940
#
#    redshift_err      u-g      g-r      r-i    far
# 0      0.000269  0.14593  0.15334 -0.06726   True
# 1      0.000021  1.61799  0.84657  0.43490  False
# 2      0.000019  1.31251  0.54459  0.30119  False

# %%
fig = px.scatter(df, x='u-g', y='g-r', color='specClass')
fig.show()
# Out:
# <div>
#
#
#             <div id="ea446d5d-4487-46bd-8224-54e995258257" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ea446d5d-4487-46bd-8224-54e995258257")) {
#                     Plotly.newPlot(
#                         'ea446d5d-4487-46bd-8224-54e995258257',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "specClass=QSO<br>u-g=%{x}<br>g-r=%{y}", "legendgroup": "specClass=QSO", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "specClass=QSO", "showlegend": true, "type": "scatter", "x": [0.1459299999999999, 0.12563000000000102, 0.5281699999999994, 0.32376000000000005, 0.4085099999999997, 0.40373000000000303, 1.1717200000000005, 1.525459999999999, 0.21676000000000073, 0.30637000000000114, 0.38537000000000177, 0.14902999999999977, 0.2874100000000013, 0.06644000000000005, 0.26820999999999984, 0.15711999999999904, 0.15616999999999948, 0.3156700000000008, 0.2053200000000004, 0.017779999999998353, 0.3012200000000007, 0.28404000000000096, 0.10931999999999675, 0.1962699999999984, 0.2697099999999999, 1.2283799999999978, 0.18496999999999986, 0.3545100000000012, 0.07190999999999903, 0.3558400000000006, 0.4130900000000004, 0.07306000000000168, 0.34240000000000137, 0.4240700000000004, 0.20042999999999722, 0.001660000000001105, 0.16519999999999868, 0.33847000000000094, 0.05743000000000009, -0.1088099999999983, 0.1860999999999997, 0.20973000000000042, 0.1843199999999996, 0.5244599999999977, 0.04953000000000074, 0.14087999999999923, 0.5342400000000005, 0.1689799999999977, 0.03263000000000105, 0.3657900000000005, 0.16588000000000136, -0.12959000000000032, 0.07520999999999844, 0.31787999999999883, 1.59211, 0.22648000000000224, 0.7754800000000017, -0.0025599999999990075, 0.22171000000000163, -0.04974999999999952, 0.0010999999999974364, 0.35243999999999787, 0.5733399999999982, -0.029380000000003292, 0.18293999999999855, 0.17585999999999657, 0.15136000000000038, 0.5845999999999982, 0.12491999999999948, 